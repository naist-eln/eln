# %% [markdown]
# # **Tutorial #1:** APIを用いたeLabFTWのノート作成

# %% [markdown]
# <b>Note:</b> ご不明な点がございましたら、lee.jemyung@naist.ac.jp にご連絡ください

# %% [markdown]
# ## **Step 1:** APIを使って簡単なデータを入れてみましょう
# #### テンプレートを読込んで実験ノートを作成し、簡単なデータを追加する基本的なAPIの使用例

# %% [markdown]
# ## 前準備
# ### 「.env」 ファイルの作成
# 実行ファイル（「\*.py」や「\*.ipynb」）と同じフォルダに以下の内容を入力して「.env」ファイルを保存する。
# <br><span style="background-color:red"><b>注</b></span>： "<b>.env</b>" というファイル名で保存してくださ。
# <br><br>
# 「.env」ファイルの内容<br>
#
# > <span style="font-size:80%"> HOST_URL='https\://makimono.elab.one/api/v2'   <span style="color: #808080">　<- この部分は変更しません</span></span><br>
# > <span style="font-size:80%"> API_KEY='' <span style="color: #808080">　<-「''」の中にコピーしたAPI-KEYをペーストしてください</span></span>
#
# <span style="background-color:blue"><b>参考</b></span>：API-KEYは「Settings」→「API KEYS」→「Create new key」→「Generate an API Key」から取得できます。

# %% [markdown]
# ### コード駆動準備
# ライブラリ、パッケージ、モジュールの呼び出しと設定

# %%
import os
import elabapi_python
from elabapi_python.rest import ApiException
import json
import pandas as pd
from IPython.display import display, HTML
from bs4 import BeautifulSoup
from dotenv import load_dotenv
import warnings
from urllib3.exceptions import InsecureRequestWarning
from difflib import get_close_matches

# APIクライアントの設定
load_dotenv()
configuration = elabapi_python.Configuration()
configuration.host = os.environ["HOST_URL"]
configuration.api_key['Authorization'] = os.environ["API_KEY"]
configuration.debug = False
configuration.verify_ssl = False

# SSL警告を無効化
warnings.simplefilter('ignore', InsecureRequestWarning)

# 各種のインスタンスを作成
api_client = elabapi_python.ApiClient(configuration)
api_client.set_default_header(header_name = 'Authorization', header_value = configuration.api_key['Authorization'] )
experimentsApi = elabapi_python.ExperimentsApi(api_client)
templatesApi = elabapi_python.ExperimentsTemplatesApi(api_client)
uploadsApi = elabapi_python.UploadsApi(api_client)
itemsApi = elabapi_python.ItemsApi(api_client)

# %% [markdown]
# ## 実験ノート作成

# %% [markdown]
# ### テンプレートリストの確認
# 現在登録されているテンプレートのリストを表示します。テンプレートのIDとTitleを確認することができます。

# %%
# テンプレートIDとタイトルを取得
templates_data = []
errors = []

try:
    templates_list = templatesApi.read_experiments_templates()
    
    for template in templates_list:
        try:
            templates_data.append({
                'ID': template.id,
                'Title': template.title
            })
        except AttributeError as e:
            errors.append(f"AttributeError for template ID {template.id}: {e}")
        except Exception as e:
            errors.append(f"An error occurred for template ID {template.id}: {e}")

except ApiException as e:
    print(f"Exception when calling TemplatesApi->read_experiments_templates: {e}\n")
    if e.body:
        print(f"Error details: {e.body}\n")

# データフレームに変換して表示
templates_df = pd.DataFrame(templates_data)
templates_df[['ID']] = templates_df[['ID']].astype(str)
display(templates_df)

# エラーの内容を表示
if errors:
    print("Errors encountered:")
    for error in errors:
        print(error)
# Out:
#     ID      Title
# 0  109  Test_No.1
# 1  108  Test_No.2

# %% [markdown]
# ### テンプレート指定
# 上記のテンプレートリストを見て、使用するテンプレートのIDまたはTitleを以下に記入してください。

# %%
template_id = ""
template_title = "Test_No1"
sample_id = ""

# %% [markdown]
# ### テンプレートの割り当て
# 指定したIDまたはTitleからテンプレートを割り当て、IDとTitleを確定</br>
# コード実行時に割り当てられたIDとTitleが表示される。

# %%
detected_title = ""
try:
    if template_id and (templates_df['ID'] == template_id).any():
        detected_title = templates_df.loc[templates_df['ID'] == template_id, 'Title'].values[0]
        if not template_title:
            template_title = detected_title
    elif template_title:
        if (templates_df['Title'] == template_title).any():
            detected_title = template_title
        else:
            detected_title = get_close_matches(template_title, templates_df['Title'] , 3, 0.7)
            if detected_title:
                detected_title = detected_title[0]
            else:
                raise ValueError(f"Template title is not detected.")
        template_id = templates_df.loc[templates_df['Title'] == detected_title, 'ID'].values[0]
    else:
        raise ValueError("Please enter a valid template ID or Title, above.")
    
    print(f"Template title is assigned to \"{detected_title}\"" + ("." if detected_title == template_title else f", altered from \"{template_title}\"."))

    if template_id in templates_df['ID'].values:
        print(f"Template ID: {template_id}")
    else:
        raise ValueError(f"Template ID {template_id} not found in templates_df")
except ValueError as e:
    print("ValueError: %s\n" % e)
# Out:
# Template title is assigned to "Test_No.1", altered from "Test_No1".
# Template ID: 109

# %% [markdown]
# ### テンプレートの取得
# 割り当てられたIDのテンプレートを取得

# %%
# Prepare the body for creating an experiment
template = None
experiment_body = {
    "category_id": template_id,  # カテゴリIDを指定
}

try:
    if template_id in templates_df['ID'].values:
        template = templatesApi.get_experiment_template(template_id)
        print(f"Template (ID: {template_id}) is ready to use.")
    else:
        raise ValueError(f"Template ID {template_id} not found in templates dataframe.")
except ValueError as e:
    print("ValueError: %s\n" % e)
# Out:
# Template (ID: 109) is ready to use.

# %% [markdown]
# ### テンプレートの確認
# 取得したテンプレートを確認

# %%
try:    
    template_dict = template.to_dict()
    template_html = "<h2>Template Information</h2>"
    template_html += "<ul>"
    for key, value in template_dict.items():
        template_html += f"<li><strong>{key}:</strong> {value}</li>"
    template_html += "</ul>"
    display(HTML(template_html))
except ApiException as e:
    print(f"Exception when calling TemplatesApi->get_experiment_template: {e}\n")
    if e.body:
           print(f"Error details: {e.body}\n")
except Exception as e:
    print(f"An error occurred: {e}\n")
# Out:
# <h2>Template Information</h2><ul><li><strong>id:</strong> 109</li><li><strong>title:</strong> Test_No.1</li><li><strong>body:</strong> <h1><span style="font-size:14pt;">目的:</span></h1>
# <p> </p>
# <h1><strong><span style="font-size:14pt;">目的組成:<br></span></strong></h1>
# <table>
#
# <tr style="background-color:#c2e0f4;">
# <td style="border-color:#95a5a6;border-style:solid;">PDP (T/F)</td>
# <td style="border-color:#95a5a6;border-style:solid;">サンプルID *1<br>Sample ID</td>
# <td style="border-color:#95a5a6;border-style:solid;">目的化合物名<br>Target Compound</td>
# <td style="border-color:#95a5a6;border-style:solid;">増仕込み量 *2<br>+ α</td>
# <td style="border-color:#95a5a6;border-style:solid;">元素比率<br>Element Ratio</td>
# <td style="border-color:#95a5a6;border-style:solid;">合成方法 *3<br>Method</td>
# <td style="border-color:#95a5a6;border-style:solid;">生成物量 [g]<br>Weight of Compound</td>
# <td style="border-color:#95a5a6;border-style:solid;">生成物分子量 [g/mol]<br>Formura Weight of Compound</td>
# </tr>
# <tr style="background-color:#c2e0f4;">
# <td style="border-color:#95a5a6;border-style:solid;">PDC</td>
# <td style="border-color:#95a5a6;border-style:solid;">SampleID</td>
# <td style="border-color:#95a5a6;border-style:solid;">TargetCompound</td>
# <td style="border-color:#95a5a6;border-style:solid;">Alpha</td>
# <td style="border-color:#95a5a6;border-style:solid;">ElementRatio</td>
# <td style="border-color:#95a5a6;border-style:solid;">Method</td>
# <td style="border-color:#95a5a6;border-style:solid;">WC</td>
# <td style="border-color:#95a5a6;border-style:solid;">FWC</td>
# </tr>
# <tr>
# <td style="border-color:#95a5a6;border-style:solid;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;"> </td>
# </tr>
#
# </table>
# <p><span style="font-size:8pt;">*1 ProjectID^Date^NameID^任意の数字1^任意の数字2^... (例: cz^230726^sht^0), *2 増仕込みする元素があれば例の様に記入してください (例: Sr: +5%), *3 合成方法を記入してください<br></span></p>
# <p> </p>
# <h1><span style="font-size:14pt;">結果:</span></h1>
# <p>TS: <br>秤量</p>
# <table style="height:95.5999px;">
#
# <tr style="height:31.8667px;background-color:#c2e0f4;">
# <td style="border-color:#95a5a6;border-style:solid;height:31.8667px;">PDP (T/F)</td>
# <td style="border-color:#95a5a6;border-style:solid;height:31.8667px;">使用元素<br>Element</td>
# <td style="border-color:#95a5a6;border-style:solid;height:31.8667px;">IASO ID<br>IASO ID</td>
# <td style="border-color:#95a5a6;border-style:solid;height:31.8667px;">分子量 [g/mol]<br>Molecular Weight</td>
# <td style="border-color:#95a5a6;border-style:solid;height:31.8667px;">理論モル比 [mol%]<br>Ideal Mole Ratio</td>
# <td style="border-color:#95a5a6;border-style:solid;height:31.8667px;">理論重量比 [wt%]<br>Ideal Weight Ratio</td>
# <td style="border-color:#95a5a6;border-style:solid;height:31.8667px;">理論重量 [g]<br>Ideal Weight</td>
# <td style="border-color:#95a5a6;border-style:solid;height:31.8667px;">計量重量比 [wt%]<br>Measured Weight Ratio</td>
# <td style="border-color:#95a5a6;border-style:solid;height:31.8667px;">計量重量 [g]<br>Measured Weight</td>
# </tr>
# <tr style="height:15.9333px;background-color:#c2e0f4;">
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;">PDC</td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;">Element</td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IASO</td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;">Mw</td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IMR</td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IWR</td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IW</td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;">MWR</td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;">MW</td>
# </tr>
# <tr style="height:15.9333px;">
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# </tr>
# <tr style="height:15.9333px;">
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# </tr>
# <tr style="height:15.9333px;">
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;height:15.9333px;"> </td>
# </tr>
#
# </table>
# <p>実験条件</p>
# <table>
#
# <tr style="background-color:#c2e0f4;">
# <td style="border-color:#95a5a6;border-style:solid;">PDP (T/F)</td>
# <td style="border-color:#95a5a6;border-style:solid;">サンプルID<br>Sample ID</td>
# <td style="border-color:#95a5a6;border-style:solid;">反応温度 [oC]<br>Reaction Temperature</td>
# <td style="border-color:#95a5a6;border-style:solid;">反応時間 [h]<br>Reaction Time</td>
# </tr>
# <tr style="background-color:#c2e0f4;">
# <td style="border-color:#95a5a6;border-style:solid;">PDC</td>
# <td style="border-color:#95a5a6;border-style:solid;">SampleID</td>
# <td style="border-color:#95a5a6;border-style:solid;">ReactionTemp</td>
# <td style="border-color:#95a5a6;border-style:solid;">ReactionTime</td>
# </tr>
# <tr>
# <td style="border-color:#95a5a6;border-style:solid;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;"> </td>
# <td style="border-color:#95a5a6;border-style:solid;"> </td>
# </tr>
#
# </table>
# <p>TS: <br>試料の真空引き</p>
# <p>TS: <br>熱処理 (120oC, 1h)</p>
# <p>TS: <br>真空封入</p>
# <p>TS: <br>熱処理</p>
# <p>TS: <br>試料取り出し</p>
# <p>TS: <br>試料粉砕</p>
# <p>TS: <br>Znを溶かし出す前のXRDを測定</p>
# <table>
#
# <tr style="background-color:#c2e0f4;">
# <td style="border-color:#95a5a6;border-style:solid;">PDP (T/F)</td>
# <td style="border-color:#95a5a6;border-style:solid;">サンプルID<br>Sample ID</td>
# <td style="border-color:#95a5a6;border-style:solid;">結晶相1 (NaOH処理前)<br>Phase-1 (before NaOH)</td>
# <td style="border-color:#95a5a6;border-style:solid;">結晶相2 (NaOH処理前)<br>Phase-2 (before NaOH)</td>
# <td style="border-color:#95a5a6;border-style:solid;">結晶相3 (NaOH処理前)<br>Phase-3 (before NaOH)</td>
# <td style="border-color:#95a5a6;border-style:solid;">結晶相4 (NaOH処理前)<br>Phase-4 (before NaOH)</td>
# <td st

# %% [markdown]
# ### 実験ノートの準備
# テンプレートから「(Template title)_(Sample ID)」をタイトルにする実験ノートを作成する。</br>
# 正常に作成できていたら、その結果を出力し確認する。

# %%
try:
    # テンプレートIDがデータフレームに存在するか確認
    if template_id not in templates_df['ID'].values:
        display(templates_df)
        print(template_id, " ", type(template_id))
        raise ValueError(f"Template ID {template_id} not found in templates_df")

    # テンプレートIDに対応するタイトルを取得
    tmpl_title = templates_df.loc[templates_df['ID'] == template_id, 'Title'].values[0]
    
    # 新しいタイトルを作成
    new_title = f"{tmpl_title}_{sample_id}"
    
    # 実験ノートの内容を設定
    experiment_body = {
        "category_id": str(template_id)  # カテゴリIDを指定
    }
   
    # Create an experiment
    api_response = experimentsApi.post_experiment(body=experiment_body)    
    print("Experiment created successfully: ")
    if api_response: print(f"No issue.")
    else: print(api_response)

    # 新しい実験ノートのIDを取得するため、最新の実験ノートを取得
    experiments_list = sorted(experimentsApi.read_experiments(), key=lambda x: x._date, reverse=True)
    new_experiment_id = experiments_list[0].id

    # 実験ノートのタイトルを更新
    update_body = {
        "title": new_title
    }
    update_response = experimentsApi.patch_experiment(new_experiment_id, body=update_body)
    print("Experiment title updated successfully:")
    print(update_response)

except ValueError as e:
    print("ValueError: %s\n" % e)
except ApiException as e:
    print("Exception when calling ExperimentsApi->post_experiment or patch_experiment: %s\n" % e)
    if e.body:
        print(f"Error details: {e.body}\n")
except Exception as e:
    print("An error occurred: %s\n" % e)
# Out:
# Experiment created successfully:
# None
# Experiment title updated successfully:
# {'_date': '2024-11-07',
#  'access_key': None,
#  'body': '<h1><span style="font-size:14pt;">目的:</span></h1>\n'
#          '<p>\xa0</p>\n'
#          '<h1><strong><span '
#          'style="font-size:14pt;">目的組成:<br></span></strong></h1>\n'
#          '<table>\n'
#          '\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDP (T/F)</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">サンプルID '
#          '*1<br>Sample ID</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;">目的化合物名<br>Target '
#          'Compound</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">増仕込み量 *2<br>+ '
#          'α</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">元素比率<br>Element '
#          'Ratio</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">合成方法 '
#          '*3<br>Method</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">生成物量 '
#          '[g]<br>Weight of Compound</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">生成物分子量 '
#          '[g/mol]<br>Formura Weight of Compound</td>\n'
#          '</tr>\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">SampleID</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;">TargetCompound</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Alpha</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;">ElementRatio</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Method</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">WC</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">FWC</td>\n'
#          '</tr>\n'
#          '<tr>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '</tr>\n'
#          '\n'
#          '</table>\n'
#          '<p><span style="font-size:8pt;">*1 '
#          'ProjectID^Date^NameID^任意の数字1^任意の数字2^... (例: cz^230726^sht^0), *2 '
#          '増仕込みする元素があれば例の様に記入してください (例: Sr: +5%), *3 '
#          '合成方法を記入してください<br></span></p>\n'
#          '<p>\xa0</p>\n'
#          '<h1><span style="font-size:14pt;">結果:</span></h1>\n'
#          '<p>TS:\xa0<br>秤量</p>\n'
#          '<table style="height:95.5999px;">\n'
#          '\n'
#          '<tr style="height:31.8667px;background-color:#c2e0f4;">\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">PDP '
#          '(T/F)</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">使用元素<br>Element</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">IASO '
#          'ID<br>IASO ID</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">分子量 '
#          '[g/mol]<br>Molecular Weight</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">理論モル比 '
#          '[mol%]<br>Ideal Mole Ratio</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">理論重量比 '
#          '[wt%]<br>Ideal Weight Ratio</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">理論重量 '
#          '[g]<br>Ideal Weight</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">計量重量比 '
#          '[wt%]<br>Measured Weight Ratio</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">計量重量 '
#          '[g]<br>Measured Weight</td>\n'
#          '</tr>\n'
#          '<tr style="height:15.9333px;background-color:#c2e0f4;">\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">PDC</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">Element</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IASO</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">Mw</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IMR</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IWR</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IW</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">MWR</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">MW</td>\n'
#          '</tr>\n'
#          '<tr style="height:15.9333px;">\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '</tr>\n'
#          '<tr style="height:15.9333px;">\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '</tr>\n'
#          '<tr style="height:15.9333px;">\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '</tr>\n'
#          '\n'
#          '</table>\n'
#          '<p>実験条件</p>\n'
#          '<table>\n'
#          '\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDP (T/F)</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;">サンプルID<br>Sample '
#          'ID</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">反応温度 '
#          '[oC]<br>Reaction Temperature</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">反応時間 '
#          '[h]<br>Reaction Time</td>\n'
#          '</tr>\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">SampleID</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;">ReactionTemp</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;">ReactionTime</td>\n'
#          '</tr>\n'
#          '<tr>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '</tr>\n'
#          '\n'
#          '</table>\n'
#          '<p>TS:\xa0<br>試料の真空引き</p>\n'
#          '<p>TS:\xa0<br>熱処理 (120oC, 1h)</p>\n'
#          '<p>TS:\xa0<br>真空封入</p>\n'
#          '<p>TS:\xa0<br>熱処理</p>\n'
#          '<p>TS:\xa0<br>試料取り出し</p>\n'
#          '<p>TS:\xa0<br>試料粉砕</p>\n'
#          '<p>TS:\xa0<br>Znを溶かし出す前のXRDを測定</p>\n'
#          '<table>\n'
#          '\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDP (T/F)</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;">サンプルID<br>Sample '
#          'ID</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相1 '
#          '(NaOH処理前)<br>Phase-1 (before NaOH)</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相2 '
#          '(NaOH処理前)<br>Phase-2 (before NaOH)</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相3 '
#          '(NaOH処理前)<br>Phase-3 (before NaOH)</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相4 '
#          '(NaOH処理前)<br>Phase-4 (before NaOH)</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相5 '
#          '(NaOH処理前)<br>Phase-5 (before NaOH)</td>\n'
#          '</tr>\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">SampleID</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase1-BN</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase2-BN</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase3-BN</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase4-BN</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase5-BN</td>\n'
#          '</tr>\n'
#          '<tr>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '</tr>\n'
#          '\n'
#          '</table>\n'
#          '<p>TS:\xa0<br>試料の半分を水酸化ナトリウム水溶液入れてZnを溶かし出し</p>\n'
#          '<p>NaOH \xa0 g H2O 100 mL\u3000である。</p>\n'
#          '<p>TS:\xa0<br>試料回収</p>\n'
#          '<p>TS:\xa0<br>Znを溶かし出した後のXRDを測定</p>\n'
#          '<table>\n'
#          '\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDP (T/F)</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;">サンプルID<br>Sample '
#          'ID</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相1 '
#          '(NaOH処理後)<br>Phase-1 (after NaOH)</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相2 '
#          '(NaOH処理後)<br>Phase-2 (after NaOH)</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相3 '
#          '(NaOH処理後)<br>Phase-3 (after NaOH)</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相4 '
#          '(NaOH処理後)<br>Phase-4 (after NaOH)</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相5 '
#          '(NaOH処理後)<br>Phase-5 (after NaOH)</td>\n'
#          '</tr>\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">SampleID</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase1-AN</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase2-AN</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase3-AN</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase4-AN</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase5-AN</td>\n'
#          '</tr>\n'
#          '<tr>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '</tr>\n'
#          '\n'
#          '</table>\n'
#          '<p><span '
#          'style="font-size:14pt;"><strong>分析データリンク先:</strong></span></p>\n'
#          '<table>\n'
#          '\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDP (T/F)</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;">分析装置<br>Analysis '
#          'Equipment</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">分析データ保管場所 '
#          '*5<br>Analysis Data Storage Location</td>\n'
#          '</tr>\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">AE</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">ADSL</td>\n'
#          '</tr>\n'
#          '<tr>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">XRD</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '</tr>\n'
#          '\n'
#          '</table>\n'
#          '<p><span style="font-size:8pt;">*4 '
#          '各ファイルが保管さいれているフォルダのサーバの情報を記入してください (例: '
#          'smb://fsx-p04.naist.jp/mi-lab-all/research/experiment/Fundamental_Alloy/XRD/20230213)</span></p>\n'
#          '<p>\xa0</p>\n'
#          '<h1><span style="font-size:14pt;">考察:</span></h1>\n'
#          '<p>\xa0</p>\n'
#          '<h1><span style="font-size:14pt;">次やること:</span></h1>\n'
#          '<p>\xa0</p>\n'
#          '<h1><span style="font-size:14pt;">雑感:</span></h1>\n'
#          '<p>\xa0</p>',
#  'body_html': '<h1><span style="font-size:14pt;">目的:</span></h1>\n'
#               '<p>\xa0</p>\n'
#               '<h1><strong><span '
#               'style="font-size:14pt;">目的組成:<br></span></strong></h1>\n'
#               '<table>\n'
#               '\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDP '
#               '(T/F)</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">サンプルID '
#               '*1<br>Sample ID</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">目的化合物名<br>Target '
#               'Compound</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">増仕込み量 '
#               '*2<br>+ α</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">元素比率<br>Element '
#               'Ratio</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">合成方法 '
#               '*3<br>Method</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">生成物量 '
#               '[g]<br>Weight of Compound</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">生成物分子量 '
#               '[g/mol]<br>Formura Weight of Compound</td>\n'
#               '</tr>\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">SampleID</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">TargetCompound</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Alpha</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">ElementRatio</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Method</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">WC</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">FWC</td>\n'
#               '</tr>\n'
#               '<tr>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '</tr>\n'
#               '\n'
#               '</table>\n'
#               '<p><span style="font-size:8pt;">*1 '
#               'ProjectID^Date^NameID^任意の数字1^任意の数字2^... (例: cz^230726^sht^0), '
#               '*2 増仕込みする元素があれば例の様に記入してください (例: Sr: +5%), *3 '
#               '合成方法を記入してください<br></span></p>\n'
#               '<p>\xa0</p>\n'
#               '<h1><span style="font-size:14pt;">結果:</span></h1>\n'
#               '<p>TS:\xa0<br>秤量</p>\n'
#               '<table style="height:95.5999px;">\n'
#               '\n'
#               '<tr style="height:31.8667px;background-color:#c2e0f4;">\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">PDP '
#               '(T/F)</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">使用元素<br>Element</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">IASO '
#               'ID<br>IASO ID</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">分子量 '
#               '[g/mol]<br>Molecular Weight</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">理論モル比 '
#               '[mol%]<br>Ideal Mole Ratio</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">理論重量比 '
#               '[wt%]<br>Ideal Weight Ratio</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">理論重量 '
#               '[g]<br>Ideal Weight</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">計量重量比 '
#               '[wt%]<br>Measured Weight Ratio</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">計量重量 '
#               '[g]<br>Measured Weight</td>\n'
#               '</tr>\n'
#               '<tr style="height:15.9333px;background-color:#c2e0f4;">\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">PDC</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">Element</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IASO</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">Mw</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IMR</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IWR</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IW</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">MWR</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">MW</td>\n'
#               '</tr>\n'
#               '<tr style="height:15.9333px;">\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '</tr>\n'
#               '<tr style="height:15.9333px;">\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '</tr>\n'
#               '<tr style="height:15.9333px;">\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '</tr>\n'
#               '\n'
#               '</table>\n'
#               '<p>実験条件</p>\n'
#               '<table>\n'
#               '\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDP '
#               '(T/F)</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">サンプルID<br>Sample '
#               'ID</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">反応温度 '
#               '[oC]<br>Reaction Temperature</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">反応時間 '
#               '[h]<br>Reaction Time</td>\n'
#               '</tr>\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">SampleID</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">ReactionTemp</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">ReactionTime</td>\n'
#               '</tr>\n'
#               '<tr>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '</tr>\n'
#               '\n'
#               '</table>\n'
#               '<p>TS:\xa0<br>試料の真空引き</p>\n'
#               '<p>TS:\xa0<br>熱処理 (120oC, 1h)</p>\n'
#               '<p>TS:\xa0<br>真空封入</p>\n'
#               '<p>TS:\xa0<br>熱処理</p>\n'
#               '<p>TS:\xa0<br>試料取り出し</p>\n'
#               '<p>TS:\xa0<br>試料粉砕</p>\n'
#               '<p>TS:\xa0<br>Znを溶かし出す前のXRDを測定</p>\n'
#               '<table>\n'
#               '\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDP '
#               '(T/F)</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">サンプルID<br>Sample '
#               'ID</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相1 '
#               '(NaOH処理前)<br>Phase-1 (before NaOH)</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相2 '
#               '(NaOH処理前)<br>Phase-2 (before NaOH)</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相3 '
#               '(NaOH処理前)<br>Phase-3 (before NaOH)</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相4 '
#               '(NaOH処理前)<br>Phase-4 (before NaOH)</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相5 '
#               '(NaOH処理前)<br>Phase-5 (before NaOH)</td>\n'
#               '</tr>\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">SampleID</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase1-BN</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase2-BN</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase3-BN</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase4-BN</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase5-BN</td>\n'
#               '</tr>\n'
#               '<tr>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '</tr>\n'
#               '\n'
#               '</table>\n'
#               '<p>TS:\xa0<br>試料の半分を水酸化ナトリウム水溶液入れてZnを溶かし出し</p>\n'
#               '<p>NaOH \xa0 g H2O 100 mL\u3000である。</p>\n'
#               '<p>TS:\xa0<br>試料回収</p>\n'
#               '<p>TS:\xa0<br>Znを溶かし出した後のXRDを測定</p>\n'
#               '<table>\n'
#               '\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDP '
#               '(T/F)</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">サンプルID<br>Sample '
#               'ID</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相1 '
#               '(NaOH処理後)<br>Phase-1 (after NaOH)</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相2 '
#               '(NaOH処理後)<br>Phase-2 (after NaOH)</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相3 '
#               '(NaOH処理後)<br>Phase-3 (after NaOH)</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相4 '
#               '(NaOH処理後)<br>Phase-4 (after NaOH)</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相5 '
#               '(NaOH処理後)<br>Phase-5 (after NaOH)</td>\n'
#               '</tr>\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">SampleID</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase1-AN</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase2-AN</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase3-AN</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase4-AN</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase5-AN</td>\n'
#               '</tr>\n'
#               '<tr>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '</tr>\n'
#               '\n'
#               '</table>\n'
#               '<p><span '
#               'style="font-size:14pt;"><strong>分析データリンク先:</strong></span></p>\n'
#               '<table>\n'
#               '\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDP '
#               '(T/F)</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">分析装置<br>Analysis '
#               'Equipment</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">分析データ保管場所 '
#               '*5<br>Analysis Data Storage Location</td>\n'
#               '</tr>\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">AE</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">ADSL</td>\n'
#               '</tr>\n'
#               '<tr>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">XRD</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '</tr>\n'
#               '\n'
#               '</table>\n'
#               '<p><span style="font-size:8pt;">*4 '
#               '各ファイルが保管さいれているフォルダのサーバの情報を記入してください (例: '
#               'smb://fsx-p04.naist.jp/mi-lab-all/research/experiment/Fundamental_Alloy/XRD/20230213)</span></p>\n'
#               '<p>\xa0</p>\n'
#               '<h1><span style="font-size:14pt;">考察:</span></h1>\n'
#               '<p>\xa0</p>\n'
#               '<h1><span style="font-size:14pt;">次やること:</span></h1>\n'
#               '<p>\xa0</p>\n'
#               '<h1><span style="font-size:14pt;">雑感:</span></h1>\n'
#               '<p>\xa0</p>',
#  'canread': '{"base": 30, "teams": [], "users": [], "teamgroups": []}',
#  'canwrite': '{"base": 20, "teams": [], "users": [], "teamgroups": []}',
#  'category': None,
#  'category_color': None,
#  'category_title': None,
#  'comments': [],
#  'content_type': 1,
#  'created_at': '2024-11-07 17:09:56',
#  'custom_id': None,
#  'elabid': '20241107-7d2c33621d8806084b97334e107507b312394e2d',
#  'experiments_links': [],
#  'firstname': 'jemyung',
#  'fullname': 'jemyung lee',
#  'has_attachement': None,
#  'has_comment': 0,
#  'id': 1906,
#  'items_links': [],
#  'lastchangeby': 131,
#  'lastname': 'lee',
#  'locked': 0,
#  'locked_at': None,
#  'lockedby': None,
#  'metadata': None,
#  'modified_at': '2024-11-07 17:09:57',
#  'next_step': '計算に使用したExcel等を添付する',
#  'orcid': None,
#  'page': 'experiments',
#  'rating': 0,
#  'recent_comment': None,
#  'related_experiments_links': [],
#  'related_items_links': [],
#  'sharelink': 'https://makimono.elab.one/experiments.php?mode=view&id=1906',
#  'state': 1,
#  'status': None,
#  'status_color': None,
#  'status_title': None,
#  'steps': [{'body': '計算に使用したExcel等を添付する',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4388,
#             'item_id': 1906,
#             'ordering': 0},
#            {'body': '秤量',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4389,
#             'item_id': 1906,
#             'ordering': 1},
#            {'body': '試料の真空引き',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4390,
#             'item_id': 1906,
#             'ordering': 2},
#            {'body': '熱処理 (120oC, 1h)',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4391,
#             'item_id': 1906,
#             'ordering': 3},
#            {'body': '真空封入',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4392,
#             'item_id': 1906,
#             'ordering': 4},
#            {'body': '熱処理',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4393,
#             'item_id': 1906,
#             'ordering': 5},
#            {'body': '試料取り出し',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4394,
#             'item_id': 1906,
#             'ordering': 6},
#            {'body': '試料粉砕',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4395,
#             'item_id': 1906,
#             'ordering': 7},
#            {'body': 'Znを溶かし出す前のXRDを測定',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4396,
#             'item_id': 1906,
#             'ordering': 8},
#            {'body': '試料の半分を水酸化ナトリウム水溶液入れてZnを溶かし出し',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4397,
#             'item_id': 1906,
#             'ordering': 9},
#            {'body': ' 試料回収 ',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4398,
#             'item_id': 1906,
#             'ordering': 10},
#            {'body': 'Znを溶かし出した後のXRDを測定',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4399,
#             'item_id': 1906,
#             'ordering': 11}],
#  'tags': 'Catalyst|Zinc',
#  'tags_id': '256,257',
#  'team': 16,
#  'timestamped': 0,
#  'timestamped_at': None,
#  'timestampedby': None,
#  'title': 'Test_No.1_',
#  'type': 'experiments',
#  'up_item_id': None,
#  'uploads': [],
#  'userid': 131}

# %% [markdown]
# ### 実験ノートリストの確認
# 作成した全実験ノートを出力する。

# %%
# 全実験ノートの確認
try:
    # デフォルト設定で実験ノートを取得
    print("デフォルト設定で実験ノートを取得:")
    experimentsList = experimentsApi.read_experiments()
    print(f"Number of experiments: {len(experimentsList)}")
    
    # 必要なフィールドを抽出してリストに格納
    exp_data = []
    for experiment in experimentsList:
        exp_dict = experiment.to_dict()
        exp_data.append({
            '_date': exp_dict.get('_date'),
            'category_title': exp_dict.get('category_title'),
            'category': exp_dict.get('category'),
            'fullname': exp_dict.get('fullname'),
            'id': exp_dict.get('id'),
            'tags': exp_dict.get('tags'),
            'tags_id': exp_dict.get('tags_id'),
            'up_item_id': exp_dict.get('up_item_id')
        })

    # データフレームに変換
    experiments_df = pd.DataFrame(exp_data)
    experiments_df['_date'] = pd.to_datetime(experiments_df['_date'])   # _date列をdatetime型に変換
    experiments_df = experiments_df.sort_values(by='_date', ascending=False)    # 作成日が新しい順にソート
    print(experiments_df)
    
except ApiException as e:
    print("ExperimentsApiを呼び出す際の例外: %s\n" % e)
# Out:
# デフォルト設定で実験ノートを取得:
# Number of experiments: 12
#         _date category_title category     fullname    id           tags  \
# 0  2024-11-07           None     None  jemyung lee  1906  Catalyst|Zinc
# 1  2024-11-06           None     None  jemyung lee  1900  Catalyst|Zinc
# 2  2024-10-28           None     None  jemyung lee  1848  Catalyst|Zinc
# 3  2024-10-28           None     None  jemyung lee  1855  Catalyst|Zinc
# 4  2024-10-28           None     None  jemyung lee  1847  Catalyst|Zinc
# 5  2024-10-28           None     None  jemyung lee  1845  Catalyst|Zinc
# 6  2024-10-28           None     None  jemyung lee  1843  Catalyst|Zinc
# 7  2024-10-28           None     None  jemyung lee  1842  Catalyst|Zinc
# 8  2024-10-22           None     None  jemyung lee  1796  Catalyst|Zinc
# 9  2024-10-22           None     None  jemyung lee  1795  Catalyst|Zinc
# 10 2024-10-22           None     None  jemyung lee  1794  Catalyst|Zinc
# 11 2024-10-22           None     None  jemyung lee  1793  Catalyst|Zinc
#
#     tags_id up_item_id
# 0   256,257       None
# 1   256,257       None
# 2   256,257       None
# 3   256,257       None
# 4   256,257       None
# 5   256,257       None
# 6   256,257       None
# 7   256,257       None
# 8   256,257       None
# 9   256,257       None
# 10  256,257       None
# 11  256,257       None

# %% [markdown]
# ### 最新の実験ノートを取得
# 実験ノートリストから最新の実験ノートを取得します。</br>
# 取得した実験ノートのIDが表示されます。

# %%
try:
    experiments_list = experimentsApi.read_experiments()
    print(f"Number of experiments: {len(experiments_list)}")
    
    # 最も新しい実験ノートを取得
    if experiments_list:
        experiments_list = sorted(experiments_list, key=lambda x: x._date, reverse=True)  # 作成日でソート
        experiment_id = experiments_list[0].id  # 最新の実験ノートのIDを取得
        print(f"Selected (the latest) experiment ID: {experiment_id}")        
    else:
        print("No experiments found.")
        exit()

except ApiException as e:
    print(f"Exception when calling ExperimentsApi->read_experiments: {e}\n")
    exit()
# Out:
# Number of experiments: 12
# Selected (the latest) experiment ID: 1906

# %% [markdown]
# ## 実験ノートの内容更新

# %% [markdown]
# ### 更新内容の入力
# 実験ノートにアップデートするテーブルデータを入力します。

# %%
# 更新する実験ノートの内容を入力
update_contents = []
update_contents.append({
            'PDC': "11",
            'SampleID': "1001",
            'TargetCompound': "55",
            'Alpha': "25",
            'ElementRatio': "2",
            'Method': "150",
            'WC': "30",
            'FWC': "50"
        })
update_contents.append({
            'PDC': "11",
            'Element': "55",
            'IASO': "25",
            'Mw': "2",
            'IMR': "150",
            'IWR': "30",
            'IW': "50",
            'MWR': "123",
            'MW': "456"    
        })	
update_response = ''

# %% [markdown]
# ### 実験ノートの内容を更新
# 最新の実験ノートの詳細を取得して実験ノートの内容を更新します。

# %%
# 最新の実験ノートの詳細を取得
try:
    latest_experiment_details = experimentsApi.get_experiment(experiment_id)
    current_body = latest_experiment_details.body
    current_title = latest_experiment_details.title

    # BeautifulSoupを使ってHTMLを解析
    soup = BeautifulSoup(current_body, 'html.parser')

    # 例として、特定の表のセルの内容を更新する
    
    tables = soup.find_all('table')
    
    for i, cnts in enumerate(update_contents):
        table = tables[i]
        if table:
            rows = table.find_all('tr')
            if len(rows) > 1:
                items = [x.string for x in rows[1].find_all('td')]
                cells = rows[2].find_all('td')
                if len(cells) >= len(cnts):
                    for c_itm in cnts.keys():
                        ci = items.index(c_itm)
                        cells[ci].string = cnts[c_itm]
                else:
                    raise ValueError(f"Cell(s) ({len(cells)}) is(are) fewer than update contents ({len(cnts)})")
            else:
                raise ValueError(f"Insufficient rows ({len(rows)})")
        else:
            raise ValueError(f"Table(s) ({len(soup.findAll('tr'))}) is(are) fewer than update contents ({len(update_contents)})")

    # 更新されたHTMLを文字列に戻す
    updated_body = str(soup)

    # 新しい内容をもとに既存の内容を更新
    update_body = {
        "body": updated_body,  # 更新されたHTML
    }

    # 実験ノートの内容を更新
    update_response = experimentsApi.patch_experiment(experiment_id, body=update_body)
    print("Experiment has updated successfully.")
    
except ApiException as e:
    print(f"Exception when calling ExperimentsApi->patch_experiment: {e}\n")
    if e.body:
        print(f"Error details: {e.body}\n")
except Exception as e:
    print(f"An error occurred: {e}\n")
# Out:
# Experiment has updated successfully.

# %% [markdown]
# ### 更新Raw requestの確認
# 下記のコードを実行すると、APIを通じて配信したリクエストを確認することができます。

# %%
try:
    # リクエスト内容を表示
    print("Request body:")
    print(json.dumps(update_body, ensure_ascii=False, indent=2))
    
    if update_response:
        print(update_response)
    
except Exception as e:
    print(f"An error occurred: {e}\n")
# Out:
# Request body:
# {
#   "body": "<h1><span style=\"font-size:14pt;\">目的:</span></h1>\n<p> </p>\n<h1><strong><span style=\"font-size:14pt;\">目的組成:<br/></span></strong></h1>\n<table>\n<tr style=\"background-color:#c2e0f4;\">\n<td style=\"border-color:#95a5a6;border-style:solid;\">PDP (T/F)</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">サンプルID *1<br/>Sample ID</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">目的化合物名<br/>Target Compound</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">増仕込み量 *2<br/>+ α</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">元素比率<br/>Element Ratio</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">合成方法 *3<br/>Method</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">生成物量 [g]<br/>Weight of Compound</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">生成物分子量 [g/mol]<br/>Formura Weight of Compound</td>\n</tr>\n<tr style=\"background-color:#c2e0f4;\">\n<td style=\"border-color:#95a5a6;border-style:solid;\">PDC</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">SampleID</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">TargetCompound</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">Alpha</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">ElementRatio</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">Method</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">WC</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">FWC</td>\n</tr>\n<tr>\n<td style=\"border-color:#95a5a6;border-style:solid;\">11</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">1001</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">55</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">25</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">2</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">150</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">30</td>\n<td style=\"border-color:#95a5a6;border-style:solid;\">50</td>\n</tr>\n</table>\n<p><span style=\"font-size:8pt;\">*1 ProjectID^Date^NameID^任意の数字1^任意の数字2^... (例: cz^230726^sht^0), *2 増仕込みする元素があれば例の様に記入してください (例: Sr: +5%), *3 合成方法を記入してください<br/></span></p>\n<p> </p>\n<h1><span style=\"font-size:14pt;\">結果:</span></h1>\n<p>TS: <br/>秤量</p>\n<table style=\"height:95.5999px;\">\n<tr style=\"height:31.8667px;background-color:#c2e0f4;\">\n<td style=\"border-color:#95a5a6;border-style:solid;height:31.8667px;\">PDP (T/F)</td>\n<td style=\"border-color:#95a5a6;border-style:solid;height:31.8667px;\">使用元素<br/>Element</td>\n<td style=\"border-color:#95a5a6;border-style:solid;height:31.8667px;\">IASO ID<br/>IASO ID</td>\n<td style=\"border-color:#95a5a6;border-style:solid;height:31.8667px;\">分子量 [g/mol]<br/>Molecular Weight</td>\n<td style=\"border-color:#95a5a6;border-style:solid;height:31.8667px;\">理論モル比 [mol%]<br/>Ideal Mole Ratio</td>\n<td style=\"border-color:#95a5a6;border-style:solid;height:31.8667px;\">理論重量比 [wt%]<br/>Ideal Weight Ratio</td>\n<td style=\"border-color:#95a5a6;border-style:solid;height:31.8667px;\">理論重量 [g]<br/>Ideal Weight</td>\n<td style=\"border-color:#95a5a6;border-style:solid;height:31.8667px;\">計量重量比 [wt%]<br/>Measured Weight Ratio</td>\n<td style=\"border-color:#95a5a6;border-style:solid;height:31.8667px;\">計量重量 [g]<br/>Measured Weight</td>\n</tr>\n<tr style=\"height:15.9333px;background-color:#c2e0f4;\">\n<td style=\"border-color:#95a5a6;border-style:solid;height:15.9333px;\">PDC</td>\n<td style=\"border-color:#95a5a6;border-style:solid;height:15.9333px;\">Element</td>\n<td style=\"border-color:#95a5a6;border-style:solid;height:15.9333px;\">IASO</td>\n<td style=\"border-color:#95a5a6;border-style:solid;height:15.9333px;\">Mw</td>\n<td style=\"border-color:#95a5a6;border-style:solid;height:15.9333px;\">IMR</td>\n<td style=\"border-color:#95a5a6;border-style:solid;height:15.9333px;\">IWR</td>\n<td style=\"border-color:#95a5a6;border-style:solid;height:15.9333px;\">IW</td>\n<td style=\"border-color:#95a ...
# }
# {'_date': '2024-11-07',
#  'access_key': None,
#  'body': '<h1><span style="font-size:14pt;">目的:</span></h1>\n'
#          '<p>\xa0</p>\n'
#          '<h1><strong><span '
#          'style="font-size:14pt;">目的組成:<br></span></strong></h1>\n'
#          '<table>\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDP (T/F)</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">サンプルID '
#          '*1<br>Sample ID</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;">目的化合物名<br>Target '
#          'Compound</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">増仕込み量 *2<br>+ '
#          'α</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">元素比率<br>Element '
#          'Ratio</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">合成方法 '
#          '*3<br>Method</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">生成物量 '
#          '[g]<br>Weight of Compound</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">生成物分子量 '
#          '[g/mol]<br>Formura Weight of Compound</td>\n'
#          '</tr>\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">SampleID</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;">TargetCompound</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Alpha</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;">ElementRatio</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Method</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">WC</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">FWC</td>\n'
#          '</tr>\n'
#          '<tr>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">11</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">1001</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">55</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">25</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">2</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">150</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">30</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">50</td>\n'
#          '</tr>\n'
#          '</table>\n'
#          '<p><span style="font-size:8pt;">*1 '
#          'ProjectID^Date^NameID^任意の数字1^任意の数字2^... (例: cz^230726^sht^0), *2 '
#          '増仕込みする元素があれば例の様に記入してください (例: Sr: +5%), *3 '
#          '合成方法を記入してください<br></span></p>\n'
#          '<p>\xa0</p>\n'
#          '<h1><span style="font-size:14pt;">結果:</span></h1>\n'
#          '<p>TS:\xa0<br>秤量</p>\n'
#          '<table style="height:95.5999px;">\n'
#          '<tr style="height:31.8667px;background-color:#c2e0f4;">\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">PDP '
#          '(T/F)</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">使用元素<br>Element</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">IASO '
#          'ID<br>IASO ID</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">分子量 '
#          '[g/mol]<br>Molecular Weight</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">理論モル比 '
#          '[mol%]<br>Ideal Mole Ratio</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">理論重量比 '
#          '[wt%]<br>Ideal Weight Ratio</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">理論重量 '
#          '[g]<br>Ideal Weight</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">計量重量比 '
#          '[wt%]<br>Measured Weight Ratio</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">計量重量 '
#          '[g]<br>Measured Weight</td>\n'
#          '</tr>\n'
#          '<tr style="height:15.9333px;background-color:#c2e0f4;">\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">PDC</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">Element</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IASO</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">Mw</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IMR</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IWR</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IW</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">MWR</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">MW</td>\n'
#          '</tr>\n'
#          '<tr style="height:15.9333px;">\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">11</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">55</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">25</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">2</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">150</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">30</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">50</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">123</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">456</td>\n'
#          '</tr>\n'
#          '<tr style="height:15.9333px;">\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '</tr>\n'
#          '<tr style="height:15.9333px;">\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#          '</td>\n'
#          '</tr>\n'
#          '</table>\n'
#          '<p>実験条件</p>\n'
#          '<table>\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDP (T/F)</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;">サンプルID<br>Sample '
#          'ID</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">反応温度 '
#          '[oC]<br>Reaction Temperature</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">反応時間 '
#          '[h]<br>Reaction Time</td>\n'
#          '</tr>\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">SampleID</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;">ReactionTemp</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;">ReactionTime</td>\n'
#          '</tr>\n'
#          '<tr>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '</tr>\n'
#          '</table>\n'
#          '<p>TS:\xa0<br>試料の真空引き</p>\n'
#          '<p>TS:\xa0<br>熱処理 (120oC, 1h)</p>\n'
#          '<p>TS:\xa0<br>真空封入</p>\n'
#          '<p>TS:\xa0<br>熱処理</p>\n'
#          '<p>TS:\xa0<br>試料取り出し</p>\n'
#          '<p>TS:\xa0<br>試料粉砕</p>\n'
#          '<p>TS:\xa0<br>Znを溶かし出す前のXRDを測定</p>\n'
#          '<table>\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDP (T/F)</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;">サンプルID<br>Sample '
#          'ID</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相1 '
#          '(NaOH処理前)<br>Phase-1 (before NaOH)</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相2 '
#          '(NaOH処理前)<br>Phase-2 (before NaOH)</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相3 '
#          '(NaOH処理前)<br>Phase-3 (before NaOH)</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相4 '
#          '(NaOH処理前)<br>Phase-4 (before NaOH)</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相5 '
#          '(NaOH処理前)<br>Phase-5 (before NaOH)</td>\n'
#          '</tr>\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">SampleID</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase1-BN</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase2-BN</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase3-BN</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase4-BN</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase5-BN</td>\n'
#          '</tr>\n'
#          '<tr>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '</tr>\n'
#          '</table>\n'
#          '<p>TS:\xa0<br>試料の半分を水酸化ナトリウム水溶液入れてZnを溶かし出し</p>\n'
#          '<p>NaOH \xa0 g H2O 100 mL\u3000である。</p>\n'
#          '<p>TS:\xa0<br>試料回収</p>\n'
#          '<p>TS:\xa0<br>Znを溶かし出した後のXRDを測定</p>\n'
#          '<table>\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDP (T/F)</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;">サンプルID<br>Sample '
#          'ID</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相1 '
#          '(NaOH処理後)<br>Phase-1 (after NaOH)</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相2 '
#          '(NaOH処理後)<br>Phase-2 (after NaOH)</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相3 '
#          '(NaOH処理後)<br>Phase-3 (after NaOH)</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相4 '
#          '(NaOH処理後)<br>Phase-4 (after NaOH)</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">結晶相5 '
#          '(NaOH処理後)<br>Phase-5 (after NaOH)</td>\n'
#          '</tr>\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">SampleID</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase1-AN</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase2-AN</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase3-AN</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase4-AN</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">Phase5-AN</td>\n'
#          '</tr>\n'
#          '<tr>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '</tr>\n'
#          '</table>\n'
#          '<p><span '
#          'style="font-size:14pt;"><strong>分析データリンク先:</strong></span></p>\n'
#          '<table>\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDP (T/F)</td>\n'
#          '<td '
#          'style="border-color:#95a5a6;border-style:solid;">分析装置<br>Analysis '
#          'Equipment</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">分析データ保管場所 '
#          '*5<br>Analysis Data Storage Location</td>\n'
#          '</tr>\n'
#          '<tr style="background-color:#c2e0f4;">\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">AE</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">ADSL</td>\n'
#          '</tr>\n'
#          '<tr>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">XRD</td>\n'
#          '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#          '</tr>\n'
#          '</table>\n'
#          '<p><span style="font-size:8pt;">*4 '
#          '各ファイルが保管さいれているフォルダのサーバの情報を記入してください (例: '
#          'smb://fsx-p04.naist.jp/mi-lab-all/research/experiment/Fundamental_Alloy/XRD/20230213)</span></p>\n'
#          '<p>\xa0</p>\n'
#          '<h1><span style="font-size:14pt;">考察:</span></h1>\n'
#          '<p>\xa0</p>\n'
#          '<h1><span style="font-size:14pt;">次やること:</span></h1>\n'
#          '<p>\xa0</p>\n'
#          '<h1><span style="font-size:14pt;">雑感:</span></h1>\n'
#          '<p>\xa0</p>',
#  'body_html': '<h1><span style="font-size:14pt;">目的:</span></h1>\n'
#               '<p>\xa0</p>\n'
#               '<h1><strong><span '
#               'style="font-size:14pt;">目的組成:<br></span></strong></h1>\n'
#               '<table>\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDP '
#               '(T/F)</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">サンプルID '
#               '*1<br>Sample ID</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">目的化合物名<br>Target '
#               'Compound</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">増仕込み量 '
#               '*2<br>+ α</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">元素比率<br>Element '
#               'Ratio</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">合成方法 '
#               '*3<br>Method</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">生成物量 '
#               '[g]<br>Weight of Compound</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">生成物分子量 '
#               '[g/mol]<br>Formura Weight of Compound</td>\n'
#               '</tr>\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">SampleID</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">TargetCompound</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Alpha</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">ElementRatio</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Method</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">WC</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">FWC</td>\n'
#               '</tr>\n'
#               '<tr>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">11</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">1001</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">55</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">25</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">2</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">150</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">30</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">50</td>\n'
#               '</tr>\n'
#               '</table>\n'
#               '<p><span style="font-size:8pt;">*1 '
#               'ProjectID^Date^NameID^任意の数字1^任意の数字2^... (例: cz^230726^sht^0), '
#               '*2 増仕込みする元素があれば例の様に記入してください (例: Sr: +5%), *3 '
#               '合成方法を記入してください<br></span></p>\n'
#               '<p>\xa0</p>\n'
#               '<h1><span style="font-size:14pt;">結果:</span></h1>\n'
#               '<p>TS:\xa0<br>秤量</p>\n'
#               '<table style="height:95.5999px;">\n'
#               '<tr style="height:31.8667px;background-color:#c2e0f4;">\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">PDP '
#               '(T/F)</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">使用元素<br>Element</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">IASO '
#               'ID<br>IASO ID</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">分子量 '
#               '[g/mol]<br>Molecular Weight</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">理論モル比 '
#               '[mol%]<br>Ideal Mole Ratio</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">理論重量比 '
#               '[wt%]<br>Ideal Weight Ratio</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">理論重量 '
#               '[g]<br>Ideal Weight</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">計量重量比 '
#               '[wt%]<br>Measured Weight Ratio</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:31.8667px;">計量重量 '
#               '[g]<br>Measured Weight</td>\n'
#               '</tr>\n'
#               '<tr style="height:15.9333px;background-color:#c2e0f4;">\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">PDC</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">Element</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IASO</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">Mw</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IMR</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IWR</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">IW</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">MWR</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">MW</td>\n'
#               '</tr>\n'
#               '<tr style="height:15.9333px;">\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">11</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">55</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">25</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">2</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">150</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">30</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">50</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">123</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">456</td>\n'
#               '</tr>\n'
#               '<tr style="height:15.9333px;">\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '</tr>\n'
#               '<tr style="height:15.9333px;">\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;height:15.9333px;">\xa0'
#               '</td>\n'
#               '</tr>\n'
#               '</table>\n'
#               '<p>実験条件</p>\n'
#               '<table>\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDP '
#               '(T/F)</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">サンプルID<br>Sample '
#               'ID</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">反応温度 '
#               '[oC]<br>Reaction Temperature</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">反応時間 '
#               '[h]<br>Reaction Time</td>\n'
#               '</tr>\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">SampleID</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">ReactionTemp</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">ReactionTime</td>\n'
#               '</tr>\n'
#               '<tr>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '</tr>\n'
#               '</table>\n'
#               '<p>TS:\xa0<br>試料の真空引き</p>\n'
#               '<p>TS:\xa0<br>熱処理 (120oC, 1h)</p>\n'
#               '<p>TS:\xa0<br>真空封入</p>\n'
#               '<p>TS:\xa0<br>熱処理</p>\n'
#               '<p>TS:\xa0<br>試料取り出し</p>\n'
#               '<p>TS:\xa0<br>試料粉砕</p>\n'
#               '<p>TS:\xa0<br>Znを溶かし出す前のXRDを測定</p>\n'
#               '<table>\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDP '
#               '(T/F)</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">サンプルID<br>Sample '
#               'ID</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相1 '
#               '(NaOH処理前)<br>Phase-1 (before NaOH)</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相2 '
#               '(NaOH処理前)<br>Phase-2 (before NaOH)</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相3 '
#               '(NaOH処理前)<br>Phase-3 (before NaOH)</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相4 '
#               '(NaOH処理前)<br>Phase-4 (before NaOH)</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相5 '
#               '(NaOH処理前)<br>Phase-5 (before NaOH)</td>\n'
#               '</tr>\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">SampleID</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase1-BN</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase2-BN</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase3-BN</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase4-BN</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase5-BN</td>\n'
#               '</tr>\n'
#               '<tr>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '</tr>\n'
#               '</table>\n'
#               '<p>TS:\xa0<br>試料の半分を水酸化ナトリウム水溶液入れてZnを溶かし出し</p>\n'
#               '<p>NaOH \xa0 g H2O 100 mL\u3000である。</p>\n'
#               '<p>TS:\xa0<br>試料回収</p>\n'
#               '<p>TS:\xa0<br>Znを溶かし出した後のXRDを測定</p>\n'
#               '<table>\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDP '
#               '(T/F)</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">サンプルID<br>Sample '
#               'ID</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相1 '
#               '(NaOH処理後)<br>Phase-1 (after NaOH)</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相2 '
#               '(NaOH処理後)<br>Phase-2 (after NaOH)</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相3 '
#               '(NaOH処理後)<br>Phase-3 (after NaOH)</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相4 '
#               '(NaOH処理後)<br>Phase-4 (after NaOH)</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">結晶相5 '
#               '(NaOH処理後)<br>Phase-5 (after NaOH)</td>\n'
#               '</tr>\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">SampleID</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase1-AN</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase2-AN</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase3-AN</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase4-AN</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">Phase5-AN</td>\n'
#               '</tr>\n'
#               '<tr>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '</tr>\n'
#               '</table>\n'
#               '<p><span '
#               'style="font-size:14pt;"><strong>分析データリンク先:</strong></span></p>\n'
#               '<table>\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDP '
#               '(T/F)</td>\n'
#               '<td '
#               'style="border-color:#95a5a6;border-style:solid;">分析装置<br>Analysis '
#               'Equipment</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">分析データ保管場所 '
#               '*5<br>Analysis Data Storage Location</td>\n'
#               '</tr>\n'
#               '<tr style="background-color:#c2e0f4;">\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">PDC</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">AE</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">ADSL</td>\n'
#               '</tr>\n'
#               '<tr>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">XRD</td>\n'
#               '<td style="border-color:#95a5a6;border-style:solid;">\xa0</td>\n'
#               '</tr>\n'
#               '</table>\n'
#               '<p><span style="font-size:8pt;">*4 '
#               '各ファイルが保管さいれているフォルダのサーバの情報を記入してください (例: '
#               'smb://fsx-p04.naist.jp/mi-lab-all/research/experiment/Fundamental_Alloy/XRD/20230213)</span></p>\n'
#               '<p>\xa0</p>\n'
#               '<h1><span style="font-size:14pt;">考察:</span></h1>\n'
#               '<p>\xa0</p>\n'
#               '<h1><span style="font-size:14pt;">次やること:</span></h1>\n'
#               '<p>\xa0</p>\n'
#               '<h1><span style="font-size:14pt;">雑感:</span></h1>\n'
#               '<p>\xa0</p>',
#  'canread': '{"base": 30, "teams": [], "users": [], "teamgroups": []}',
#  'canwrite': '{"base": 20, "teams": [], "users": [], "teamgroups": []}',
#  'category': None,
#  'category_color': None,
#  'category_title': None,
#  'comments': [],
#  'content_type': 1,
#  'created_at': '2024-11-07 17:09:56',
#  'custom_id': None,
#  'elabid': '20241107-7d2c33621d8806084b97334e107507b312394e2d',
#  'experiments_links': [],
#  'firstname': 'jemyung',
#  'fullname': 'jemyung lee',
#  'has_attachement': None,
#  'has_comment': 0,
#  'id': 1906,
#  'items_links': [],
#  'lastchangeby': 131,
#  'lastname': 'lee',
#  'locked': 0,
#  'locked_at': None,
#  'lockedby': None,
#  'metadata': None,
#  'modified_at': '2024-11-07 17:10:10',
#  'next_step': '計算に使用したExcel等を添付する',
#  'orcid': None,
#  'page': 'experiments',
#  'rating': 0,
#  'recent_comment': None,
#  'related_experiments_links': [],
#  'related_items_links': [],
#  'sharelink': 'https://makimono.elab.one/experiments.php?mode=view&id=1906',
#  'state': 1,
#  'status': None,
#  'status_color': None,
#  'status_title': None,
#  'steps': [{'body': '計算に使用したExcel等を添付する',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4388,
#             'item_id': 1906,
#             'ordering': 0},
#            {'body': '秤量',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4389,
#             'item_id': 1906,
#             'ordering': 1},
#            {'body': '試料の真空引き',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4390,
#             'item_id': 1906,
#             'ordering': 2},
#            {'body': '熱処理 (120oC, 1h)',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4391,
#             'item_id': 1906,
#             'ordering': 3},
#            {'body': '真空封入',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4392,
#             'item_id': 1906,
#             'ordering': 4},
#            {'body': '熱処理',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4393,
#             'item_id': 1906,
#             'ordering': 5},
#            {'body': '試料取り出し',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4394,
#             'item_id': 1906,
#             'ordering': 6},
#            {'body': '試料粉砕',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4395,
#             'item_id': 1906,
#             'ordering': 7},
#            {'body': 'Znを溶かし出す前のXRDを測定',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4396,
#             'item_id': 1906,
#             'ordering': 8},
#            {'body': '試料の半分を水酸化ナトリウム水溶液入れてZnを溶かし出し',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4397,
#             'item_id': 1906,
#             'ordering': 9},
#            {'body': ' 試料回収 ',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4398,
#             'item_id': 1906,
#             'ordering': 10},
#            {'body': 'Znを溶かし出した後のXRDを測定',
#             'deadline': None,
#             'deadline_notif': 0,
#             'finished': 0,
#             'finished_time': None,
#             'id': 4399,
#             'item_id': 1906,
#             'ordering': 11}],
#  'tags': 'Catalyst|Zinc',
#  'tags_id': '256,257',
#  'team': 16,
#  'timestamped': 0,
#  'timestamped_at': None,
#  'timestampedby': None,
#  'title': 'Test_No.1_',
#  'type': 'experiments',
#  'up_item_id': None,
#  'uploads': [],
#  'userid': 131}

# %% [markdown]
# #### 次へ
# お疲れ様でした。次のステップのための準備ができました。次のステップに進むには、ここをクリックしてください。
